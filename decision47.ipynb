# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
df=pd.read_csv('DCSON - Sheet1.csv')
print(df)
d={'UK':0,'USA':1,'N':2}
df['NATIONALITY']=df['NATIONALITY'].map(d)
features=['EXPERIENCE','RANK','NATIONALITY']
X=df[features]
y=df['GO']
dtree=DecisionTreeClassifier()
dtree=dtree.fit(X,y)
tree.plot_tree(dtree,feature_names=features)
plt.show()
# Out:
#     AGE   EXPERIENCE  RANK NATIONALITY   GO
# 0     36          10     9          UK   NO
# 1     42          12     4         USA   NO
# 2     23           4     6           N   NO
# 3     52           4     4         USA   NO
# 4     43          21     8         USA  YES
# 5     44          14     5          UK   NO
# 6     66           3     7           N  YES
# 7     35          14     9          UK  YES
# 8     24          13     5         USA   NO
# 9     18           7     7          UK  YES
# 10    45           9     9          UK  YES
